# %% [markdown]
# # **creating tuple**
#
# **tuples are read only datatypes**

# %% [markdown]
# * **empty tuples**

# %%
t=()
t

# %%
# homogenous tuple

t1=(1,2,3,4)
t1
# Out:
# (1, 2, 3, 4)

# %%
# heterogemeous tuples

t2=(1,2.3,3,'s',"Shek")
t2
# Out:
# (1, 2.3, 3, 's', 'Shek')

# %% [markdown]
# # multidimensional tuples

# %%
t3=(1,2,3,(4,5))

t3
# Out:
# (1, 2, 3, (4, 5))

# %% [markdown]
# **single item tuple** --> requires a comma after the single element

# %%
t4=(1)
print(t4)
type(t4)
# Out:
# 1
# int

# %%
t4a=("Hello")
print(t4a)
type(t4a)
# Out:
# Hello
# str

# %%
t4=(1,)
print(t4)
type(t4)
# Out:
# (1,)
# tuple

# %% [markdown]
# # **using tuple() functions**

# %%
t5=tuple("Goa")
t5
# Out:
# ('G', 'o', 'a')

# %%
t6=tuple([1,2,3,4])
t6
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# #**accesing items similar to list**

# %%
t2
# Out:
# (1, 2.3, 3, 's', 'Shek')

# %%
t2[:3]
# Out:
# (1, 2.3, 3)

# %%
t2[::-1]
# Out:
# ('Shek', 's', 3, 2.3, 1)

# %%
t3
# Out:
# (1, 2, 3, (4, 5))

# %%
t3[-1]
# Out:
# (4, 5)

# %%
t3[-1][0]
# Out:
# 4

# %% [markdown]
# #**tuples are unmutable similar to string unlike lists**
# **no addition allowed in tuples**

# %%
t2
# Out:
# (1, 2.3, 3, 's', 'Shek')

# %%
t2[-1]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-39c52de9fc96> in <cell line: 1>()
# ----> 1 t2[-1]=5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # deleting a tuples --> we can anly delete whole tuples not a part of it due to imutability

# %%
t
# Out:
# ()

# %%
del(t)

# %%
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-34fc7a11cb38> in <cell line: 1>()
# ----> 1 t
#
# NameError: name 't' is not defined

# %%
t1
# Out:
# (1, 2, 3, 4)

# %%
del(t1[-1])
t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-85fe6f95501a> in <cell line: 1>()
# ----> 1 del(t1[-1])
#       2 t1
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# #**Operations on tuples**

# %%
t1
# Out:
# (1, 2, 3, 4)

# %%
t2
# Out:
# (1, 2.3, 3, 's', 'Shek')

# %%
t1+t2
# Out:
# (1, 2, 3, 4, 1, 2.3, 3, 's', 'Shek')

# %%
t1*2
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)

# %%
for i in  t2:
  print(i)
# Out:
# 1
# 2.3
# 3
# s
# Shek

# %%
1 in t1
# Out:
# True

# %% [markdown]
# #**Functions of tuples**

# %%
len(t2)
# Out:
# 5

# %%
t2
# Out:
# (1, 2.3, 3, 's', 'Shek')

# %%
t1
# Out:
# (1, 2, 3, 4)

# %%
max(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-c4f83a43986d> in <cell line: 1>()
# ----> 1 max(t2)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
min(t1)
# Out:
# 1

# %%
sum(t1)
# Out:
# 10

# %%
sum(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-3fd5fddf4b2a> in <cell line: 1>()
# ----> 1 sum(t2)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
sorted(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-49f73470a3e7> in <cell line: 1>()
# ----> 1 sorted(t2)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
sorted(t1,reverse=True)
# Out:
# [4, 3, 2, 1]

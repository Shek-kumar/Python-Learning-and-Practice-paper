# %% [markdown]
# #**Strings**
# Strings are sequence of Characters
#
# In Python specifically, strings are a sequence of Unicode Characters
#
# * Creating Strings
# * Accessing Strings
# * Adding Chars to Strings
# * Editing Strings
# * Deleting Strings
# * Operations on Strings
# * String Functions

# %%
# Creating strings

c='hi'
print(c)
# Out:
# hi

# %%
S2='''this is a multiline string'''
print(S2)
# Out:
# this is a multiline string

# %%
S3=str("Shek")
S3
# Out:
# 'Shek'

# %% [markdown]
# #**indexing and slicing**

# %%
s='Hello_world'

# %%
print(s[0])
print(s[5])
print(s[-1])
print(s[-5])
# Out:
# H
# _
# d
# w

# %%
# Slicing

print(s[0:7])
print(s[2:7])
# Out:
# Hello_w
# llo_w

# %%
print(s[2:])
# Out:
# llo_world

# %%
print(s[:5])

print()

print(s[-5:-1])
# Out:
# Hello
#
# worl

# %%
s[:]
# Out:
# 'Hello_world'

# %%
# slicing with another parameter for gapings

s[0:9:2]
# Out:
# 'Hlowr'

# %%
print(s[-1:-5:-1])
# Out:
# dlro

# %%
print(s[-5:-1:2])
# Out:
# wr

# %%
print(s[::-1])
# Out:
# dlrow_olleH

# %% [markdown]
# #**Edition and deletion in strings**
#
# * strings are immutable

# %%
c='Hello'

print(c)
# Out:
# Hello

# %%
c='world'
print(c)
# Out:
# world

# %%
del c

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-1dd5973cae19> in <cell line: 1>()
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %% [markdown]
# #**Opertaors on strings**
#
#
# \
# * # Arimethic operators

# %%
# Adition

'hello'+'_'+ 'world'
# Out:
# 'hello_world'

# %%
# multiplication

print("Hi_Shek\n"*10)
# Out:
# Hi_Shek
# Hi_Shek
# Hi_Shek
# Hi_Shek
# Hi_Shek
# Hi_Shek
# Hi_Shek
# Hi_Shek
# Hi_Shek
# Hi_Shek

# %% [markdown]
# # Relational Operators

# %%
'Hi'=='Hi'
# Out:
# True

# %%
'Hi'!='hi'
# Out:
# True

# %% [markdown]
# * Lexiographically comparison
# * small letters comes later as compared to capital letters
# * P comes late as compared to M

# %%
'Mumbai'>'Pune'
# Out:
# False

# %%
'Goa'>'Gaya'
# Out:
# True

# %% [markdown]
# #Logical Operators

# %% [markdown]
# * empty string(" ") is --> False
# * non-empty string --> True

# %%
'Hello' and 'Shek'
# Out:
# 'Shek'

# %%
"" and "Shek"
# Out:
# ''

# %%
"" or "Sk"
# Out:
# 'Sk'

# %%
"hi" or "Sk"
# Out:
# 'hi'

# %%
not ''
# Out:
# True

# %%
not "Shek"
# Out:
# False

# %% [markdown]
# #**Loops on strings**

# %%
c="SHEKHAR KUMAR"

for i in (c):
  print(i)
# Out:
# S
# H
# E
# K
# H
# A
# R
#
# K
# U
# M
# A
# R

# %%
for i in c[:6]:
  print(i)
# Out:
# S
# H
# E
# K
# H
# A

# %%
for i in c[::-1]:
  print(i)
# Out:
# R
# A
# M
# U
# K
#
# R
# A
# H
# K
# E
# H
# S

# %% [markdown]
# #**Membership operator**

# %%
c
# Out:
# 'SHEKHAR KUMAR'

# %%
'h' in  c
# Out:
# False

# %%
'H' in c
# Out:
# True

# %%
"SHEK" in c
# Out:
# True

# %% [markdown]
# #**Functions in strings**
#
#
# * **Common functions**

# %%
c
# Out:
# 'SHEKHAR KUMAR'

# %%
len(c)
# Out:
# 13

# %%
min(c)
# Out:
# ' '

# %%
max(c)
# Out:
# 'U'

# %%
sorted(c)
# Out:
# [' ', 'A', 'A', 'E', 'H', 'H', 'K', 'K', 'M', 'R', 'R', 'S', 'U']

# %%
sorted(c,reverse=True)
# Out:
# ['U', 'S', 'R', 'R', 'M', 'K', 'K', 'H', 'H', 'E', 'A', 'A', ' ']

# %% [markdown]
# #**1. Capitalize/Title/Upper/Lower/Swapcase**

# %%
c="hELlo My name IS ShekhaR KUMar okAy!!"

c.capitalize()
# Out:
# 'Hello my name is shekhar kumar okay!!'

# %%
c.title()
# Out:
# 'Hello My Name Is Shekhar Kumar Okay!!'

# %%
c.upper()
# Out:
# 'HELLO MY NAME IS SHEKHAR KUMAR OKAY!!'

# %%
c.lower()
# Out:
# 'hello my name is shekhar kumar okay!!'

# %%
# Upper to lower  and vice versa

c.swapcase()
# Out:
# 'HelLO mY NAME is sHEKHAr kumAR OKaY!!'

# %% [markdown]
# #**Count function**

# %%
c="hELlo My name IS ShekhaR KUMar okAy!!"

# %%
c.count('a')
# Out:
# 3

# %%
c.count("A")
# Out:
# 1

# %%
c.count("h")
# Out:
# 3

# %% [markdown]
# #**Find/Index**

# %%
c
# Out:
# 'hELlo My name IS ShekhaR KUMar okAy!!'

# %%
c.find('y')
# Out:
# 7

# %%
c.find('z')
# Out:
# -1

# %%
c.find("Is")
# Out:
# -1

# %%
c.find("IS")
# Out:
# 14

# %%
c.index('y')
# Out:
# 7

# %%
c.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-f83f2fb6807f> in <cell line: 1>()
# ----> 1 c.index('z')
#
# ValueError: substring not found

# %% [markdown]
# #**endswith//startswith**

# %%
c
# Out:
# 'hELlo My name IS ShekhaR KUMar okAy!!'

# %%
c.endswith('y')
# Out:
# False

# %%
c.endswith('!')
# Out:
# True

# %%
c.startswith('h')
# Out:
# True

# %%
c.startswith('hEll')
# Out:
# False

# %% [markdown]
# #**format**

# %%
print("My name is {} and my age is {}".format("Shek",20))
# Out:
# My name is Shek and my age is 20

# %%
print("My name is {0} and my age is {0}".format("Shek",20))
# Out:
# My name is Shek and my age is Shek

# %%
print("My name is {0} and my age is {1}".format("Shek",20))
# Out:
# My name is Shek and my age is 20

# %%
# not allowed
# print("My name is {1} and my age is {name}".format(name="Shek",age=20))

print("My name is {age} and my age is {wt}".format(name="Shek",age=20,wt=80))
# Out:
# My name is 20 and my age is 80

# %% [markdown]
# #**6. isalnum/ isalpha/ isdecimal/ isdigit/ isidentifier**

# %%
"Float20".isalnum()
# Out:
# True

# %%
'!Float20'.isalnum()
# Out:
# False

# %%
'Float20'.isalpha()
# Out:
# False

# %%
'Flat'.isalpha()
# Out:
# True

# %%
'20'.isdigit()
# Out:
# True

# %%
'20a'.isdigit()
# Out:
# False

# %%
'name_shek'.isidentifier()
# Out:
# True

# %%
'name shek'.isidentifier()
# Out:
# False

# %% [markdown]
# #**Split()**

# %%
c
# Out:
# 'hELlo My name IS ShekhaR KUMar okAy!!'

# %%
c.split()
# Out:
# ['hELlo', 'My', 'name', 'IS', 'ShekhaR', 'KUMar', 'okAy!!']

# %%
c.split('a')
# Out:
# ['hELlo My n', 'me IS Shekh', 'R KUM', 'r okAy!!']

# %% [markdown]
# #**Join**
# * to create url

# %%
'a'.join(['hELlo My n', 'me IS Shekh', 'R KUM', 'r okAy!!'])
# Out:
# 'hELlo My name IS ShekhaR KUMar okAy!!'

# %%
"//".join(['hELlo', 'My', 'name', 'IS', 'ShekhaR', 'KUMar', 'okAy!!']
)
# Out:
# 'hELlo//My//name//IS//ShekhaR//KUMar//okAy!!'

# %% [markdown]
# #**Replace**

# %%
c
# Out:
# 'hELlo My name IS ShekhaR KUMar okAy!!'

# %%
c.replace("ShekhaR","Shekhar")
# Out:
# 'hELlo My name IS Shekhar KUMar okAy!!'

# %%
c.replace("IS",'is')
# Out:
# 'hELlo My name is ShekhaR KUMar okAy!!'

# %% [markdown]
# #**lstrip/rstrip/strip**
#
# * removes leading spaces

# %%
name='            Shekhar        '


'hi'+name
# Out:
# 'hi            Shekhar        '

# %%
'hi'+name.lstrip()
# Out:
# 'hiShekhar        '

# %%
'hi'+name.rstrip()
# Out:
# 'hi            Shekhar'

# %%
'hi'+name.strip()
# Out:
# 'hiShekhar'
